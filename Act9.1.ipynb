# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import statsmodels.api as sm

mpl.style.use('ggplot')

df=pd.read_csv('datasets/antropometria-dataset.csv')
df.head(3)
# Out:
#     folio  intp  entidad        desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21          PUEBLA     2    38      8  73.70     2
# 1  101655     3       10         DURANGO     2    11     11  35.65     2
# 2   10287     6        1  AGUASCALIENTES     2    18      8  54.80     1
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
#
#   est_urb est_marg       pondef  est_var
# 0       3        1  3470.002176      215
# 1       1        1   417.946672      101
# 2       3        1   472.980811       15
#
# [3 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
vars = ['diastol','sistol','edad','peso','cintura']
df = df[vars]
df.head(3)
# Out:
#    diastol  sistol  edad   peso  cintura
# 0    53.25   63.25    38  73.70     98.7
# 1    50.00   70.00    11  35.65     64.0
# 2    41.00   70.50    18  54.80     67.6

# %%
df = df[vars].dropna()
df.head(3)
# Out:
#    diastol  sistol  edad   peso  cintura
# 0    53.25   63.25    38  73.70     98.7
# 1    50.00   70.00    11  35.65     64.0
# 2    41.00   70.50    18  54.80     67.6

# %%
df[vars].corr()
# Out:
#           diastol    sistol      edad      peso   cintura
# diastol  1.000000  0.662332  0.344207  0.361438  0.362961
# sistol   0.662332  1.000000  0.535053  0.355847  0.403265
# edad     0.344207  0.535053  1.000000  0.318568  0.478879
# peso     0.361438  0.355847  0.318568  1.000000  0.791677
# cintura  0.362961  0.403265  0.478879  0.791677  1.000000

# %%
model = sm.OLS.from_formula('diastol~sistol+edad+peso+cintura', data=df)

result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                diastol   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     3812.
# Date:                Fri, 10 Sep 2021   Prob (F-statistic):               0.00
# Time:                        06:35:00   Log-Likelihood:                -63952.
# No. Observations:               18032   AIC:                         1.279e+05
# Df Residuals:                   18027   BIC:                         1.280e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.3297      0.520     39.089      0.000      19.310      21.349
# sistol         0.4140      0.004     94.447      0.000       0.405       0.423
# edad          -0.0272      0.004     -6.934      0.000      -0.035      -0.020
# peso           0.0825      0.006     14.154      0.000       0.071       0.094
# cintura        0.0202      0.007      3.072      0.002       0.007       0.033
# ==============================================================================
# Omnibus:                     1031.138   Durbin-Watson:                   1.769
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3722.633
# Skew:                           0.189   Prob(JB):                         0.00
# Kurtosis:                       5.194   Cond. No.                     1.39e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
